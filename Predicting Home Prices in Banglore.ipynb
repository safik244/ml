# %%
import pandas as pd
df = pd.read_csv("bengaluru_house_prices.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df = df.drop(['availability','society','society'],axis='columns')

# %%
df.shape
# Out:
# (13320, 7)

# %%
df.isna().sum()
# Out:
# area_type       0
# location        1
# size           16
# total_sqft      0
# bath           73
# balcony       609
# price           0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# area_type     0
# location      0
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# dtype: int64

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
df['bhk'] = df['size'].apply(lambda x:int(x.split(" ")[0]))

# %%
df
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK       1715
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath  balcony   price  bhk
# 0       2.0      1.0   39.07    2
# 1       5.0      3.0  120.00    4
# 2       2.0      3.0   62.00    3
# 3       3.0      1.0   95.00    3
# 4       2.0      1.0   51.00    2
# ...     ...      ...     ...  ...
# 13314   3.0      3.0  112.00    3
# 13315   4.0      0.0  231.00    5
# 13317   2.0      1.0   60.00    2
# 13318   4.0      1.0  488.00    4
# 13319   1.0      1.0   17.00    1
#
# [12710 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# area_type     0
# location      0
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# bhk           0
# dtype: int64

# %%
df['bhk'] = df['size'].apply(lambda x: int(x.split(' ')[0]))
df.bhk.unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  7,  5, 11,  9, 27, 43, 14, 12, 10, 13],
#       dtype=int64)

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df[~df['total_sqft'].apply(is_float)].head(10)
# Out:
#                 area_type               location       size      total_sqft  \
# 30   Super built-up  Area              Yelahanka      4 BHK     2100 - 2850
# 122  Super built-up  Area                 Hebbal      4 BHK     3067 - 8156
# 137  Super built-up  Area     8th Phase JP Nagar      2 BHK     1042 - 1105
# 165  Super built-up  Area               Sarjapur      2 BHK     1145 - 1340
# 188  Super built-up  Area               KR Puram      2 BHK     1015 - 1540
# 410  Super built-up  Area                Kengeri      1 BHK  34.46Sq. Meter
# 549  Super built-up  Area            Hennur Road      2 BHK     1195 - 1440
# 661  Super built-up  Area              Yelahanka      2 BHK     1120 - 1145
# 672        Built-up  Area           Bettahalsoor  4 Bedroom     3090 - 5002
# 772  Super built-up  Area  Banashankari Stage VI      2 BHK     1160 - 1195
#
#      bath  balcony    price  bhk
# 30    4.0      0.0  186.000    4
# 122   4.0      0.0  477.000    4
# 137   2.0      0.0   54.005    2
# 165   2.0      0.0   43.490    2
# 188   2.0      0.0   56.800    2
# 410   1.0      0.0   18.500    1
# 549   2.0      0.0   63.770    2
# 661   2.0      0.0   48.130    2
# 672   4.0      0.0  445.000    4
# 772   2.0      0.0   59.935    2

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df4 = df.copy()
df4.total_sqft = df4.total_sqft.apply(convert_sqft_to_num)
df4 = df4[df4.total_sqft.notnull()]
df4.head(2)
# Out:
#               area_type                  location       size  total_sqft  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
#
#    bath  balcony   price  bhk
# 0   2.0      1.0   39.07    2
# 1   5.0      3.0  120.00    4

# %%
df4.loc[30]
# Out:
# area_type     Super built-up  Area
# location                 Yelahanka
# size                         4 BHK
# total_sqft                  2475.0
# bath                           4.0
# balcony                        0.0
# price                        186.0
# bhk                              4
# Name: 30, dtype: object

# %%
df5 = df4.copy()
df5['price_per_sqft'] = df5['price']*100000/df5['total_sqft']
df5.head()
# Out:
#               area_type                  location       size  total_sqft  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2        Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4  Super built-up  Area                  Kothanur      2 BHK      1200.0
#
#    bath  balcony   price  bhk  price_per_sqft
# 0   2.0      1.0   39.07    2     3699.810606
# 1   5.0      3.0  120.00    4     4615.384615
# 2   2.0      3.0   62.00    3     4305.555556
# 3   3.0      1.0   95.00    3     6245.890861
# 4   2.0      1.0   51.00    2     4250.000000

# %%
location_stats = df5['location'].value_counts(ascending=False)
location_stats
# Out:
# location
# Whitefield           513
# Sarjapur  Road       372
# Electronic City      300
# Kanakpura Road       259
# Thanisandra          230
#                     ...
# S R Layout             1
# Meenakshi Layout       1
# Vidyapeeta             1
# Maruthi Extension      1
# Abshot Layout          1
# Name: count, Length: 1259, dtype: int64

# %%
location_stats.values.sum()
# Out:
# 12668

# %%
len(location_stats[location_stats>10])
# Out:
# 235

# %%
len(location_stats)
# Out:
# 1259

# %%
len(location_stats[location_stats<=10])
# Out:
# 1024

# %%
location_stats_less_than_10 = location_stats[location_stats<=10]
location_stats_less_than_10
# Out:
# location
# Kalkere                 10
# Nagappa Reddy Layout    10
# Basapura                10
# Doddaballapur           10
# HAL 2nd Stage           10
#                         ..
# S R Layout               1
# Meenakshi Layout         1
# Vidyapeeta               1
# Maruthi Extension        1
# Abshot Layout            1
# Name: count, Length: 1024, dtype: int64

# %%
len(df5.location.unique())
# Out:
# 1259

# %%
df5.location = df5.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
len(df5.location.unique())
# Out:
# 236

# %%
df5[df5.total_sqft/df5.bhk<300]
# Out:
#             area_type          location       size  total_sqft  bath  balcony  \
# 58         Plot  Area     Murugeshpalya  6 Bedroom      1407.0   4.0      1.0
# 68         Plot  Area             other  8 Bedroom      1350.0   7.0      0.0
# 70         Plot  Area             other  3 Bedroom       500.0   3.0      2.0
# 78     Built-up  Area  Kaval Byrasandra      2 BHK       460.0   1.0      0.0
# 89         Plot  Area      Rajaji Nagar  6 Bedroom       710.0   6.0      3.0
# ...               ...               ...        ...         ...   ...      ...
# 13219      Plot  Area           Laggere  7 Bedroom      1590.0   9.0      3.0
# 13221      Plot  Area             other  9 Bedroom      1178.0   9.0      1.0
# 13281      Plot  Area   Margondanahalli  5 Bedroom      1375.0   5.0      1.0
# 13303      Plot  Area    Vidyaranyapura  5 Bedroom       774.0   5.0      3.0
# 13311      Plot  Area  Ramamurthy Nagar  7 Bedroom      1500.0   9.0      2.0
#
#        price  bhk  price_per_sqft
# 58     150.0    6    10660.980810
# 68      85.0    8     6296.296296
# 70     100.0    3    20000.000000
# 78      22.0    2     4782.608696
# 89     160.0    6    22535.211268
# ...      ...  ...             ...
# 13219  132.0    7     8301.886792
# 13221   75.0    9     6366.723260
# 13281  125.0    5     9090.909091
# 13303   70.0    5     9043.927649
# 13311  250.0    7    16666.666667
#
# [655 rows x 9 columns]

# %%
df5.shape
# Out:
# (12668, 9)

# %%
df6 = df5[~(df5.total_sqft/df5.bhk<300)]
df6.shape
# Out:
# (12013, 9)

# %%
import numpy as np
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sqft)
        st = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df7 = remove_pps_outliers(df6)
df7.shape
# Out:
# (9853, 9)

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df8 = remove_bhk_outliers(df7)
# df8 = df7.copy()
df8.shape
# Out:
# (7026, 9)

# %%
df8.bath.unique()
# Out:
# array([ 2.,  3.,  4.,  8.,  1.,  5.,  6.,  7.,  9., 13.])

# %%
df8[df8.bath>10]
# Out:
#                  area_type location    size  total_sqft  bath  balcony  price  \
# 9267  Super built-up  Area    other  13 BHK      5425.0  13.0      0.0  275.0
#
#       bhk  price_per_sqft
# 9267   13     5069.124424

# %%
df8[df8.bath>df8.bhk+2]
# Out:
#                  area_type       location       size  total_sqft  bath  \
# 1552        Built-up  Area  Chikkabanavar  4 Bedroom      2460.0   7.0
# 6432  Super built-up  Area    Thanisandra      3 BHK      1806.0   6.0
# 8074  Super built-up  Area          other      6 BHK     11338.0   9.0
#
#       balcony   price  bhk  price_per_sqft
# 1552      2.0    80.0    4     3252.032520
# 6432      2.0   116.0    3     6423.034330
# 8074      1.0  1000.0    6     8819.897689

# %%
df9 = df8[df8.bath<df8.bhk+2]
df9.shape
# Out:
# (6959, 9)

# %%
dummies = pd.get_dummies(df5.location)

# %%
df11 = pd.concat([df5,dummies.drop('other',axis='columns')],axis='columns')
df11.head()
# Out:
#               area_type                  location       size  total_sqft  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2        Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4  Super built-up  Area                  Kothanur      2 BHK      1200.0
#
#    bath  balcony   price  bhk  price_per_sqft   Devarachikkanahalli  ...  \
# 0   2.0      1.0   39.07    2     3699.810606                 False  ...
# 1   5.0      3.0  120.00    4     4615.384615                 False  ...
# 2   2.0      3.0   62.00    3     4305.555556                 False  ...
# 3   3.0      1.0   95.00    3     6245.890861                 False  ...
# 4   2.0      1.0   51.00    2     4250.000000                 False  ...
#
#    Vijayanagar  Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  \
# 0        False                 False               False        False
# 1        False                 False               False        False
# 2        False                 False               False        False
# 3        False                 False               False        False
# 4        False                 False               False        False
#
#    Whitefield  Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  \
# 0       False           False      False               False        False
# 1       False           False      False               False        False
# 2       False           False      False               False        False
# 3       False           False      False               False        False
# 4       False           False      False               False        False
#
#    Yeshwanthpur
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 244 columns]

# %%
df12 = df11.drop('location',axis='columns')
df12
# Out:
#                   area_type       size  total_sqft  bath  balcony   price  \
# 0      Super built-up  Area      2 BHK      1056.0   2.0      1.0   39.07
# 1                Plot  Area  4 Bedroom      2600.0   5.0      3.0  120.00
# 2            Built-up  Area      3 BHK      1440.0   2.0      3.0   62.00
# 3      Super built-up  Area      3 BHK      1521.0   3.0      1.0   95.00
# 4      Super built-up  Area      2 BHK      1200.0   2.0      1.0   51.00
# ...                     ...        ...         ...   ...      ...     ...
# 13314  Super built-up  Area      3 BHK      1715.0   3.0      3.0  112.00
# 13315        Built-up  Area  5 Bedroom      3453.0   4.0      0.0  231.00
# 13317        Built-up  Area      2 BHK      1141.0   2.0      1.0   60.00
# 13318  Super built-up  Area      4 BHK      4689.0   4.0      1.0  488.00
# 13319  Super built-up  Area      1 BHK       550.0   1.0      1.0   17.00
#
#        bhk  price_per_sqft   Devarachikkanahalli  1st Block Jayanagar  ...  \
# 0        2     3699.810606                 False                False  ...
# 1        4     4615.384615                 False                False  ...
# 2        3     4305.555556                 False                False  ...
# 3        3     6245.890861                 False                False  ...
# 4        2     4250.000000                 False                False  ...
# ...    ...             ...                   ...                  ...  ...
# 13314    3     6530.612245                 False                False  ...
# 13315    5     6689.834926                 False                False  ...
# 13317    2     5258.545136                 False                False  ...
# 13318    4    10407.336319                 False                False  ...
# 13319    1     3090.909091                 False                False  ...
#
#        Vijayanagar  Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  \
# 0            False                 False               False        False
# 1            False                 False               False        False
# 2            False                 False               False        False
# 3            False                 False               False        False
# 4            False                 False               False        False
# ...            ...                   ...                 ...          ...
# 13314        False                 False               False        False
# 13315        False                 False               False        False
# 13317        False                 False               False        False
# 13318        False                 False               False        False
# 13319        False                 False               False        False
#
#        Whitefield  Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  \
# 0           False           False      False               False        False
# 1           False           False      False               False        False
# 2           False           False      False               False        False
# 3           False           False      False               False        False
# 4           False           False      False               False        False
# ...           ...             ...        ...                 ...          ...
# 13314       False           False      False               False        False
# 13315        True           False      False               False        False
# 13317       False           False      False               False        False
# 13318       False           False      False               False        False
# 13319       False           False      False               False        False
#
#        Yeshwanthpur
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 13314         False
# 13315         False
# 13317         False
# 13318         False
# 13319         False
#
# [12668 rows x 243 columns]

# %%
x = df12.drop(['price','area_type','size'],axis='columns')
y = df12['price']

# %%
x
# Out:
#        total_sqft  bath  balcony  bhk  price_per_sqft   Devarachikkanahalli  \
# 0          1056.0   2.0      1.0    2     3699.810606                 False
# 1          2600.0   5.0      3.0    4     4615.384615                 False
# 2          1440.0   2.0      3.0    3     4305.555556                 False
# 3          1521.0   3.0      1.0    3     6245.890861                 False
# 4          1200.0   2.0      1.0    2     4250.000000                 False
# ...           ...   ...      ...  ...             ...                   ...
# 13314      1715.0   3.0      3.0    3     6530.612245                 False
# 13315      3453.0   4.0      0.0    5     6689.834926                 False
# 13317      1141.0   2.0      1.0    2     5258.545136                 False
# 13318      4689.0   4.0      1.0    4    10407.336319                 False
# 13319       550.0   1.0      1.0    1     3090.909091                 False
#
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                    False               False                      False
# 1                    False               False                      False
# 2                    False               False                      False
# 3                    False               False                      False
# 4                    False               False                      False
# ...                    ...                 ...                        ...
# 13314                False               False                      False
# 13315                False               False                      False
# 13317                False               False                      False
# 13318                False               False                      False
# 13319                False               False                      False
#
#        2nd Stage Nagarbhavi  ...  Vijayanagar  Vishveshwarya Layout  \
# 0                     False  ...        False                 False
# 1                     False  ...        False                 False
# 2                     False  ...        False                 False
# 3                     False  ...        False                 False
# 4                     False  ...        False                 False
# ...                     ...  ...          ...                   ...
# 13314                 False  ...        False                 False
# 13315                 False  ...        False                 False
# 13317                 False  ...        False                 False
# 13318                 False  ...        False                 False
# 13319                 False  ...        False                 False
#
#        Vishwapriya Layout  Vittasandra  Whitefield  Yelachenahalli  Yelahanka  \
# 0                   False        False       False           False      False
# 1                   False        False       False           False      False
# 2                   False        False       False           False      False
# 3                   False        False       False           False      False
# 4                   False        False       False           False      False
# ...                   ...          ...         ...             ...        ...
# 13314               False        False       False           False      False
# 13315               False        False        True           False      False
# 13317               False        False       False           False      False
# 13318               False        False       False           False      False
# 13319               False        False       False           False      False
#
#        Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 0                   False        False         False
# 1                   False        False         False
# 2                   False        False         False
# 3                   False        False         False
# 4                   False        False         False
# ...                   ...          ...           ...
# 13314               False        False         False
# 13315               False        False         False
# 13317               False        False         False
# 13318               False        False         False
# 13319               False        False         False
#
# [12668 rows x 240 columns]

# %%
y
# Out:
# 0         39.07
# 1        120.00
# 2         62.00
# 3         95.00
# 4         51.00
#           ...
# 13314    112.00
# 13315    231.00
# 13317     60.00
# 13318    488.00
# 13319     17.00
# Name: price, Length: 12668, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.tree import DecisionTreeRegressor
lr_clf = DecisionTreeRegressor(criterion='friedman_mse',splitter='best')
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.983694861760679

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

s = cross_val_score(DecisionTreeRegressor(criterion='friedman_mse',splitter='best'), x, y, cv=cv)
s
# Out:
# array([0.97307856, 0.95370677, 0.98572293, 0.97958224, 0.98064639])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(x,y):
    algos ={
    'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# C:\Users\safik\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\safik\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\safik\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\safik\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\safik\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\safik\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.95529305 0.90175531]
#   warnings.warn(
#            model  best_score  \
# 0          lasso   -0.421633
# 1  decision_tree    0.955293
#
#                                          best_params
# 0                {'alpha': 1, 'selection': 'cyclic'}
# 1  {'criterion': 'friedman_mse', 'splitter': 'best'}
